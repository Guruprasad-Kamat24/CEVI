# %%
# % matplotlib inline
import skimage
print(skimage.__version__)
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
import PIL.ImageStat as stat
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import invert, random_noise, montage
import matplotlib.image as mpimg
import matplotlib.pylab as plt
from scipy.ndimage import affine_transform, zoom
from scipy import misc
# Out:
# 0.18.3

# %% [markdown]
# ## PIL liabrary

# %%
im = Image.open("/content/drive/MyDrive/Workshop_Dataset/lenna.png")
print(im.width,im.height,im.mode,im.format,type(im))
im.show()
# Out:
# 512 512 RGB PNG <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
im = mpimg.imread("/content/drive/MyDrive/Workshop_Dataset/lenna.png")
print(im.shape,im.dtype,type(im))
plt.figure(figsize=(10,10))
plt.imshow(im)
plt.axis('off')
plt.show()
# Out:
# (512, 512, 3) float32 <class 'numpy.ndarray'>

# %%
im = imread("/content/drive/MyDrive/HSG/Rochan.jpeg")
im_hsv =color.rgb2hsv(im)
plt.gray()
plt.figure(figsize=(10,8))
plt.subplot(221), plt.imshow(im_hsv [...,0]), plt.title('h', size=28),
plt.axis('off')
plt.subplot(222), plt.imshow(im_hsv [...,1]), plt.title('s', size=20),
plt.axis('off')
plt.subplot(223), plt.imshow(im_hsv[...,2]), plt.title('v', size=28),
plt.axis('off')
plt.subplot(224), plt.axis ('off')
plt.show()

# %%
im1=mpimg.imread("/content/drive/MyDrive/Workshop_Dataset/I01.png")
im2=mpimg.imread("/content/drive/MyDrive/Workshop_Dataset/I02.png")
i = 1
plt.figure(figsize=(18,15))
for alpha in np.linspace(0,1,20):
  plt.subplot(4,5,i) 
  plt.imshow((1-alpha)*im1 + alpha*im2) 
  plt.axis('off')
  i += 1

plt.subplots_adjust(wspace=0.05, hspace=0.05)
plt.show()
